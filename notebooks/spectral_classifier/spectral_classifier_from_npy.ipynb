# %% [markdown]
# ## 1) Daten aus CSV-Datei auslesen

# %%
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np
import os
import csv
import tensorflow as tf

########## Input ##########

fits_path = 'F:\\data\\spectral_fits'
samples_per_class = 1000

########## Program ##########

# Listen mit den flux Werten, Labels und Wellenlängen erstellen
data = np.load(fit_path + "data.npy")
labels = np.load(fit_path + "labels.npy")
wavelengths = np.load(fit_path + "wavelengths.npy")

# Liste die Galaxie-Nummer speichert
numbers = range(4*samples_per_class)

# %%
# TEST: WIEDER LÖSCHEN -> keine Verbesserung
# negative Werte werden auf 0.1 gesetzt

# for i in range(len(data)):
#     for t in range(len(data[i])):
#         if data[i][t] <= 0.1:
#             data[i][t] = 0.1

# %% [markdown]
# ## 2) Normierung

# %%
median_limit = 3
data_normalized = np.zeros(shape=(4000,3522))

# Normierungs-Test: median normalization
for i in range(len(data)):
    
    # median normalization
    sorted = np.sort(data[i])
    median = 0.5* (data[i][1760] + data[i][1761])
    data_normalized[i] = data[i]/median
    print(median)
    
    # No bigger value than 2x median
    for t in range(len(data_normalized[i])):
        if data_normalized[i][t] >= median_limit:
            data_normalized[i][t] = median_limit
            print("Datensatz " + str(i) + " oben abgeschnitten")
        elif data_normalized[i][t] <=-median_limit:
            data_normalized[i][t] = -median_limit
            print("Datensatz " + str(i) + " unten abgeschnitten")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4564/172449373.py in <module>
#       1 median_limit = 3
# ----> 2 data_normalized = np.zeros(shape=(4000,3522))
#       3
#       4 # Normierungs-Test: median normalization
#       5 for i in range(len(data)):
#
# NameError: name 'np' is not defined

# %% [markdown]
# **Ohne Normierung**

# %%
for i in [1, 2, 3, 1002, 1534, 1550, 3999]: #1534  
    plt.plot(wavelengths, data[i]) 
    plt.xlabel('wavelength(Å)') 
    plt.ylabel('flux (10-17 ergs/s/cm2/Å)') 
    plt.grid(True)
    plt.title(str(i))
    plt.show()

# %% [markdown]
# **Mit Normierung**

# %%
for i in [1,2,3,1002, 1534, 3999]:
    plt.plot(wavelengths, data_normalized[i]) 
    plt.xlabel('wavelength(Å)') 
    plt.ylabel('flux / median') 
    plt.grid(True)
    plt.title(str(i))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4564/1696242517.py in <module>
#       1 for i in [1,2,3,1002, 1534, 3999]:
# ----> 2     plt.plot(wavelengths, data_normalized[i])
#       3     plt.xlabel('wavelength(Å)')
#       4     plt.ylabel('flux / median')
#       5     plt.grid(True)
#
# NameError: name 'data_normalized' is not defined

# %% [markdown]
# ## 3) Trainings- und Test-Datensatz erstellen

# %%
import random
# z = list(zip(data_normalized, labels)) # Mit Median-Normierung
z = list(zip(data, labels, numbers)) # Ohne Median-Normierung
random.shuffle(z)
data_shuffled, labels_shuffled, numbers_shuffled = zip(*z)

# %%
print(np.array(data_shuffled).shape)
print(np.array(labels_shuffled).shape)
# Out:
# (4000, 3522)
# (4000,)

# %%
split_index = int(len(data_shuffled)*0.9)

# Daten
data_training = np.asarray(data_shuffled[:split_index])
data_test = np.asarray(data_shuffled[split_index:])

# Labels
labels_training = np.asarray(labels_shuffled[:split_index])
labels_test = np.asarray(labels_shuffled[split_index:])

# Galaxie numbers
numbers_training = numbers_shuffled[:split_index]
numbers_test = numbers_shuffled[split_index:]

# %% [markdown]
# ## 4) Netzwerk erstellen

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Flatten, Conv1D, MaxPooling1D, Dropout, InputLayer, GlobalAveragePooling1D
from tensorflow.keras.metrics import Accuracy

from tensorflow import keras
from tensorflow.keras import layers

# %%
input_shape = (3522,1)

data_training_r = np.reshape(data_training, newshape=(len(data_training), input_shape[0], input_shape[1]))
data_test_r  = np.reshape(data_test, newshape=(len(data_test), input_shape[0], input_shape[1]))

# %%
print(data_training_r.shape)
print(data_test_r.shape)
# Out:
# (3600, 3522, 1)
# (400, 3522, 1)

# %%
# Conv1D, maxPool1D, categorical_crossentropy
# model = Sequential([
#     #Conv1D(filters=30, kernel_size=10, activation='relu', input_shape=(3522,1)),
#     Conv1D(filters=64, kernel_size=5, activation='relu'), #mehr Filtern
#     MaxPooling1D(4), # Größere Region
#     Dropout(0.1),
#     #Conv1D(filters=60, kernel_size=10, activation='relu'),
#     Conv1D(filters=64, kernel_size=5, activation='relu'),
#     MaxPooling1D(4),
#     # GlobalAveragePooling1D(),
#     Dropout(0.1),
#     Flatten(),
    
#     Dense(units=64, activation='relu'),
#     #Extra Dense
    
#     Dense(units=4, activation='softmax')
# ])

# Am besten (schnell):
model = Sequential([
    Conv1D(filters=64, kernel_size=80, strides=10, activation='relu', input_shape=(3522,1)), # stride
    MaxPooling1D(3), #Pooling verringert Accuracy leicht aber verhindert overfitting
    Dropout(0.35),
    Conv1D(filters=128, kernel_size=40, strides=10, activation='relu'),
    MaxPooling1D(3),
    Dropout(0.35),
    Flatten(),
    Dense(units=128, activation='relu'), # Droput, weniger neuronen
    Dropout(0.35),
    Dense(units=4, activation='softmax')
])

# model = Sequential([
#     Conv1D(filters=64, kernel_size=40, strides=10, activation='relu', input_shape=(3522,1)), # stride
#     Dropout(0.2),
#     Conv1D(filters=128, kernel_size=20, strides=5, activation='relu'), # stride
#     Dropout(0.2),
#     Flatten(),
#     Dense(units=4, activation='softmax')
# ])

# Langsamer, aber auch gut (aus paper):
# model = Sequential([
#     Conv1D(filters=16, kernel_size=21, activation='relu', input_shape=(3522,1)),
#     MaxPooling1D(2),
#     Conv1D(filters=32, kernel_size=11, activation='relu'),
#     MaxPooling1D(2),
#     Conv1D(filters=64, kernel_size=5, activation='relu'),
#     MaxPooling1D(2),    
#     Flatten(),
#     Dense(units=64, activation='relu'),
#     Dropout(0.5),
#     Dense(units=4, activation='softmax')
# ])

# %%
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# x_train = data_training_r
# x_test = data_test_r

x_train = tf.keras.utils.normalize(data_training_r, axis=1)
x_test = tf.keras.utils.normalize(data_test_r, axis=1)

y_train = labels_training
y_test = labels_test

# %%
history = model.fit(x_train, y_train,
                    epochs=75, validation_split=0.1,
                    shuffle=True, batch_size=200,
                    verbose=1)

# model_handler=Model.Model(shape=(height_dim,height_dim,lc_dim,1))


#model3 = tf.keras.models.load_model('spectral_classifier_v2.h5')
# model.save('spectral_classifier_v2.h5')
# Out:
# Epoch 1/75
# 17/17 [==============================] - 1s 63ms/step - loss: 1.3452 - accuracy: 0.3756 - val_loss: 1.2381 - val_accuracy: 0.4694
# Epoch 2/75
# 17/17 [==============================] - 1s 58ms/step - loss: 1.1490 - accuracy: 0.4910 - val_loss: 1.0806 - val_accuracy: 0.4417
# Epoch 3/75
# 17/17 [==============================] - 1s 57ms/step - loss: 1.0436 - accuracy: 0.5176 - val_loss: 1.0260 - val_accuracy: 0.5111
# Epoch 4/75
# 17/17 [==============================] - 1s 57ms/step - loss: 1.0041 - accuracy: 0.5448 - val_loss: 0.9995 - val_accuracy: 0.5361
# Epoch 5/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.9769 - accuracy: 0.5636 - val_loss: 0.9867 - val_accuracy: 0.5389
# Epoch 6/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.9497 - accuracy: 0.5778 - val_loss: 0.9706 - val_accuracy: 0.5694
# Epoch 7/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.9272 - accuracy: 0.5747 - val_loss: 0.9427 - val_accuracy: 0.5778
# Epoch 8/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.9255 - accuracy: 0.5642 - val_loss: 0.9272 - val_accuracy: 0.5861
# Epoch 9/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.8910 - accuracy: 0.5944 - val_loss: 0.9103 - val_accuracy: 0.5889
# Epoch 10/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.8743 - accuracy: 0.5985 - val_loss: 0.8866 - val_accuracy: 0.5944
# Epoch 11/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.8581 - accuracy: 0.6068 - val_loss: 0.8818 - val_accuracy: 0.6000
# Epoch 12/75
# 17/17 [==============================] - 1s 66ms/step - loss: 0.8357 - accuracy: 0.6182 - val_loss: 0.8719 - val_accuracy: 0.5833
# Epoch 13/75
# 17/17 [==============================] - 1s 60ms/step - loss: 0.8132 - accuracy: 0.6164 - val_loss: 0.8703 - val_accuracy: 0.6028
# Epoch 14/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.7875 - accuracy: 0.6367 - val_loss: 0.8412 - val_accuracy: 0.5972
# Epoch 15/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.7755 - accuracy: 0.6478 - val_loss: 0.8003 - val_accuracy: 0.6333
# Epoch 16/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.7528 - accuracy: 0.6574 - val_loss: 0.7687 - val_accuracy: 0.6778
# Epoch 17/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.7291 - accuracy: 0.6728 - val_loss: 0.7575 - val_accuracy: 0.6583
# Epoch 18/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.7261 - accuracy: 0.6716 - val_loss: 0.7523 - val_accuracy: 0.6972
# Epoch 19/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.7011 - accuracy: 0.6849 - val_loss: 0.7105 - val_accuracy: 0.7389
# Epoch 20/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.7089 - accuracy: 0.6688 - val_loss: 0.7085 - val_accuracy: 0.6806
# Epoch 21/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.6650 - accuracy: 0.7046 - val_loss: 0.6989 - val_accuracy: 0.6944
# Epoch 22/75
# 17/17 [==============================] - 1s 61ms/step - loss: 0.6639 - accuracy: 0.6944 - val_loss: 0.6826 - val_accuracy: 0.7556
# Epoch 23/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.6538 - accuracy: 0.7031 - val_loss: 0.6775 - val_accuracy: 0.7194
# Epoch 24/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.6328 - accuracy: 0.7219 - val_loss: 0.6561 - val_accuracy: 0.7361
# Epoch 25/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.6331 - accuracy: 0.7167 - val_loss: 0.6443 - val_accuracy: 0.7667
# Epoch 26/75
# 17/17 [==============================] - 1s 60ms/step - loss: 0.6334 - accuracy: 0.7176 - val_loss: 0.6364 - val_accuracy: 0.7583
# Epoch 27/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.6166 - accuracy: 0.7222 - val_loss: 0.6430 - val_accuracy: 0.7500
# Epoch 28/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.6004 - accuracy: 0.7383 - val_loss: 0.6409 - val_accuracy: 0.7694
# Epoch 29/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.6019 - accuracy: 0.7349 - val_loss: 0.6787 - val_accuracy: 0.6972
# Epoch 30/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.5919 - accuracy: 0.7333 - val_loss: 0.6104 - val_accuracy: 0.7528
# Epoch 31/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.5878 - accuracy: 0.7395 - val_loss: 0.5983 - val_accuracy: 0.7583
# Epoch 32/75
# 17/17 [==============================] - 1s 60ms/step - loss: 0.5746 - accuracy: 0.7429 - val_loss: 0.6245 - val_accuracy: 0.7389
# Epoch 33/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.5661 - accuracy: 0.7574 - val_loss: 0.6049 - val_accuracy: 0.7722
# Epoch 34/75
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5647 - accuracy: 0.7497 - val_loss: 0.6111 - val_accuracy: 0.7556
# Epoch 35/75
# 17/17 [==============================] - 1s 62ms/step - loss: 0.5734 - accuracy: 0.7531 - val_loss: 0.5833 - val_accuracy: 0.7583
# Epoch 36/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.5571 - accuracy: 0.7497 - val_loss: 0.5806 - val_accuracy: 0.7667
# Epoch 37/75
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5587 - accuracy: 0.7497 - val_loss: 0.5927 - val_accuracy: 0.7722
# Epoch 38/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.5343 - accuracy: 0.7608 - val_loss: 0.5805 - val_accuracy: 0.7722
# Epoch 39/75
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5554 - accuracy: 0.7503 - val_loss: 0.6270 - val_accuracy: 0.7389
# Epoch 40/75
# 17/17 [==============================] - 1s 62ms/step - loss: 0.5527 - accuracy: 0.7475 - val_loss: 0.5650 - val_accuracy: 0.7778
# Epoch 41/75
# 17/17 [==============================] - 1s 61ms/step - loss: 0.5398 - accuracy: 0.7568 - val_loss: 0.5670 - val_accuracy: 0.7806
# Epoch 42/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.5272 - accuracy: 0.7809 - val_loss: 0.5635 - val_accuracy: 0.7833
# Epoch 43/75
# 17/17 [==============================] - 1s 61ms/step - loss: 0.5210 - accuracy: 0.7759 - val_loss: 0.5433 - val_accuracy: 0.7944
# Epoch 44/75
# 17/17 [==============================] - 1s 60ms/step - loss: 0.5330 - accuracy: 0.7673 - val_loss: 0.5603 - val_accuracy: 0.7861
# Epoch 45/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.5259 - accuracy: 0.7679 - val_loss: 0.5491 - val_accuracy: 0.7806
# Epoch 46/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.5174 - accuracy: 0.7713 - val_loss: 0.5485 - val_accuracy: 0.7861
# Epoch 47/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.5095 - accuracy: 0.7765 - val_loss: 0.5609 - val_accuracy: 0.7972
# Epoch 48/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.5223 - accuracy: 0.7753 - val_loss: 0.5369 - val_accuracy: 0.7750
# Epoch 49/75
# 17/17 [==============================] - 1s 60ms/step - loss: 0.5067 - accuracy: 0.7707 - val_loss: 0.5450 - val_accuracy: 0.8028
# Epoch 50/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.4947 - accuracy: 0.7880 - val_loss: 0.5392 - val_accuracy: 0.8028
# Epoch 51/75
# 17/17 [==============================] - 1s 62ms/step - loss: 0.5141 - accuracy: 0.7750 - val_loss: 0.5945 - val_accuracy: 0.7778
# Epoch 52/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.4956 - accuracy: 0.7883 - val_loss: 0.5393 - val_accuracy: 0.7889
# Epoch 53/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.5073 - accuracy: 0.7809 - val_loss: 0.5305 - val_accuracy: 0.7944
# Epoch 54/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.5034 - accuracy: 0.7855 - val_loss: 0.5306 - val_accuracy: 0.7917
# Epoch 55/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.4837 - accuracy: 0.7827 - val_loss: 0.5354 - val_accuracy: 0.7833
# Epoch 56/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.4985 - accuracy: 0.7843 - val_loss: 0.5452 - val_accuracy: 0.7861
# Epoch 57/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.4988 - accuracy: 0.7772 - val_loss: 0.5247 - val_accuracy: 0.7833
# Epoch 58/75
# 17/17 [==============================] - 1s 61ms/step - loss: 0.4844 - accuracy: 0.7873 - val_loss: 0.5338 - val_accuracy: 0.8000
# Epoch 59/75
# 17/17 [==============================] - 1s 63ms/step - loss: 0.4807 - accuracy: 0.7892 - val_loss: 0.5247 - val_accuracy: 0.7972
# Epoch 60/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4643 - accuracy: 0.8022 - val_loss: 0.5416 - val_accuracy: 0.7778
# Epoch 61/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.4807 - accuracy: 0.7951 - val_loss: 0.5386 - val_accuracy: 0.7917
# Epoch 62/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4663 - accuracy: 0.7957 - val_loss: 0.5324 - val_accuracy: 0.8056
# Epoch 63/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.4765 - accuracy: 0.7904 - val_loss: 0.5407 - val_accuracy: 0.8000
# Epoch 64/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4748 - accuracy: 0.7920 - val_loss: 0.5181 - val_accuracy: 0.7944
# Epoch 65/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.4726 - accuracy: 0.7935 - val_loss: 0.5210 - val_accuracy: 0.7917
# Epoch 66/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4741 - accuracy: 0.7892 - val_loss: 0.5099 - val_accuracy: 0.7889
# Epoch 67/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.4651 - accuracy: 0.8003 - val_loss: 0.5117 - val_accuracy: 0.8056
# Epoch 68/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.4534 - accuracy: 0.8046 - val_loss: 0.5704 - val_accuracy: 0.7889
# Epoch 69/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4638 - accuracy: 0.8012 - val_loss: 0.5165 - val_accuracy: 0.7889
# Epoch 70/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.4571 - accuracy: 0.8028 - val_loss: 0.5313 - val_accuracy: 0.8083
# Epoch 71/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4611 - accuracy: 0.7960 - val_loss: 0.5204 - val_accuracy: 0.8139
# Epoch 72/75
# 17/17 [==============================] - 1s 57ms/step - loss: 0.4494 - accuracy: 0.8099 - val_loss: 0.5106 - val_accuracy: 0.7972
# Epoch 73/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4443 - accuracy: 0.8037 - val_loss: 0.5018 - val_accuracy: 0.8056
# Epoch 74/75
# 17/17 [==============================] - 1s 59ms/step - loss: 0.4419 - accuracy: 0.8046 - val_loss: 0.4929 - val_accuracy: 0.8111
# Epoch 75/75
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4493 - accuracy: 0.8074 - val_loss: 0.5449 - val_accuracy: 0.7972

# %% [markdown]
# ## 5) Auswertungen

# %%
def plot_accuracy(name, ylim=[0,1.01]):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.ylim(ylim[0], ylim[1])
    plt.legend(['training', 'validation'], loc='upper left')
    plt.savefig(name)
    plt.show()

# %%
def plot_loss(name, ylim=[-0.5,2]):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.ylim(ylim[0],ylim[1])
    plt.legend(['training', 'validation'], loc='upper left')
    plt.savefig(name)
    plt.show()

# %%
plot_accuracy("accuracy_graph.png")
plot_loss("loss_graph.png")

# %%
from sklearn.metrics import confusion_matrix

predictions = model.predict(x=x_test)
rounded_predictions = np.argmax(predictions, axis=-1)

cm_labels = range(4)
cm = confusion_matrix(y_true=y_test, y_pred=rounded_predictions)

tf.math.confusion_matrix(
    labels=y_test, predictions=rounded_predictions, num_classes=4, weights=None, dtype=tf.dtypes.int32,
    name=None)
# Out:
# <tf.Tensor: shape=(4, 4), dtype=int32, numpy=
# array([[87,  4,  3,  1],
#        [38, 74,  4,  4],
#        [ 4,  5, 63, 15],
#        [ 0,  1, 16, 81]])>

# %% [markdown]
# ## Untersuchung der falsch klassifizierten Spektren

# %% [markdown]
# **Label 0 = AGN** \
# **Label 1 = galaxy** \
# **Label 2 = QSO** \
# **Label 3 = star**

# %%
predictions = model.predict(x=x_test)
rounded_predictions = np.argmax(predictions, axis=-1)

wrong_predictions = []

for i in range(len(rounded_predictions)):
    if rounded_predictions[i] != y_test[i]:
        wrong_predictions.append(numbers_test[i])      

wrong_predictions.sort()
        
print(len(rounded_predictions), "richtig")
print(len(wrong_predictions), "falsch")
print(str(((len(rounded_predictions)-len(wrong_predictions))/len(rounded_predictions))*100) + "% richtig klassifiziert")
# Out:
# 400 richtig
# 95 falsch
# 76.25% richtig klassifiziert

# %%
print(wrong_predictions)
# Out:
# [235, 264, 322, 459, 579, 730, 822, 968, 1003, 1029, 1038, 1048, 1058, 1066, 1134, 1139, 1180, 1249, 1267, 1277, 1316, 1331, 1339, 1357, 1374, 1380, 1393, 1488, 1493, 1494, 1504, 1509, 1516, 1544, 1556, 1591, 1621, 1642, 1657, 1687, 1733, 1738, 1762, 1766, 1774, 1776, 1820, 1825, 1838, 1841, 1856, 1864, 1916, 1953, 2028, 2077, 2207, 2208, 2274, 2371, 2426, 2467, 2559, 2567, 2616, 2667, 2679, 2687, 2754, 2765, 2799, 2830, 2840, 2880, 2907, 2940, 2965, 2986, 3021, 3035, 3044, 3064, 3106, 3219, 3233, 3303, 3348, 3375, 3401, 3462, 3465, 3527, 3568, 3681, 3937]

# %%
for i in wrong_predictions:  
    plt.plot(wavelengths, data[i]) 
    plt.xlabel('wavelength(Å)') 
    plt.ylabel('flux (10-17 ergs/s/cm2/Å)') 
    plt.grid(True)
    plt.title(str(i))
    plt.show()

# %% [markdown]
# ## Vergleichs-Benchmark

# %%
from sklearn import svm
clf = svm.SVC(gamma=0.001, C=100.)
clf.fit(data_training, labels_training)
clf.score(data_test, labels_test)
# Out:
# 0.28

# %%
from sklearn.linear_model import LogisticRegression
clf1 = LogisticRegression(max_iter=1000, random_state=123)
clf1.fit(data_training, labels_training)
clf1.score(data_test, labels_test)
# Out:
# C:\Users\Josh\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6775

# %%
from sklearn.ensemble import RandomForestClassifier
clf2 = RandomForestClassifier(n_estimators=100, random_state=123)
clf2.fit(data_training, labels_training)
clf2.score(data_test, labels_test)
# Out:
# 0.7225

# %%
from sklearn.naive_bayes import GaussianNB
clf3 = GaussianNB()
clf3.fit(data_training, labels_training)
clf3.score(data_test, labels_test)
# Out:
# 0.4225
