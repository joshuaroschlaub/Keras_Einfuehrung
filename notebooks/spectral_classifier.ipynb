# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np
import os

# %%
data = np.zeros(shape=(4000,3522,2))
# labels = np.zeros(shape=(4000,))
labels =np.empty(4000, dtype='str')

# Daten in numpy arrays data und labels einlesen
i=0
csv_path = 'F:\\data\\spectral_csv\\'

for directory in os.listdir(csv_path):

    for filename in os.listdir(csv_path + directory + '\\'):
        
        path = csv_path + '\\' + directory + '\\' + filename
        
        spectrum = np.genfromtxt(path, delimiter=",", skip_header=1)
        
        print(spectrum.shape)
        print(filename)
        data[i] = spectrum
        labels[i] = directory
        i += 1
        
# Daten normieren
# Out:
# (3522, 2)
# spec-0266-51630-0106.csv
# (3522, 2)
# spec-0267-51608-0028.csv
# (3522, 2)
# spec-0268-51633-0021.csv
# (3522, 2)
# spec-0269-51910-0105.csv
# (3522, 2)
# spec-0269-51910-0368.csv
# (3522, 2)
# spec-0270-51909-0034.csv
# (3522, 2)
# spec-0271-51883-0004.csv
# (3522, 2)
# spec-0271-51883-0322.csv
# (3522, 2)
# spec-0272-51941-0037.csv
# (3522, 2)
# spec-0273-51957-0064.csv
# (3522, 2)
# spec-0274-51913-0036.csv
# (3522, 2)
# spec-0274-51913-0141.csv
# (3522, 2)
# spec-0275-51910-0078.csv
# (3522, 2)
# spec-0276-51909-0019.csv
# (3522, 2)
# spec-0277-51908-0013.csv
# (3522, 2)
# spec-0278-51900-0097.csv
# (3522, 2)
# spec-0279-51984-0006.csv
# (3522, 2)
# spec-0280-51612-0050.csv
# (3522, 2)
# spec-0281-51614-0181.csv
# (3522, 2)
# spec-0282-51658-0030.csv
# (3522, 2)
# spec-0283-51959-0008.csv
# (3522, 2)
# spec-0283-51959-0294.csv
# (3522, 2)
# spec-0284-51943-0036.csv
# (3522, 2)
# spec-0285-51930-0016.csv
# (3522, 2)
# spec-0286-51999-0263.csv
# (3522, 2)
# spec-0287-52023-0200.csv
# (3522, 2)
# spec-0288-52000-0152.csv
# (3522, 2)
# spec-0289-51990-0102.csv
# (3522, 2)
# spec-0289-51990-0347.csv
# (3522, 2)
# spec-0290-51941-0155.csv
# (3522, 2)
# spec-0291-51928-0074.csv
# (3522, 2)
# spec-0292-51609-0035.csv
# (3522, 2)
# spec-0293-51689-0004.csv
# (3522, 2)
# spec-0294-51986-0011.csv
# (3522, 2)
# spec-0295-51985-0130.csv
# (3522, 2)
# spec-0296-51984-0104.csv
# (3522, 2)
# spec-0297-51959-0009.csv
# (3522, 2)
# spec-0298-51955-0074.csv
# (3522, 2)
# spec-0299-51671-0015.csv
# (3522, 2)
# spec-0300-51943-0009.csv
# (3522, 2)
# spec-0301-51942-0042.csv
# (3522, 2)
# spec-0302-51688-0095.csv
# (3522, 2)
# spec-0302-51688-0463.csv
# (3522, 2)
# spec-0303-51615-0105.csv
# (3522, 2)
# spec-0304-51609-0057.csv
# (3522, 2)
# spec-0305-51613-0006.csv
# (3522, 2)
# spec-0306-51637-0032.csv
# (3522, 2)
# spec-0306-51637-0251.csv
# (3522, 2)
# spec-0307-51663-0037.csv
# (3522, 2)
# spec-0308-51662-0011.csv
# (3522, 2)
# spec-0309-51994-0035.csv
# (3522, 2)
# spec-0310-51990-0085.csv
# (3522, 2)
# spec-0311-51665-0073.csv
# (3522, 2)
# spec-0312-51689-0003.csv
# (3522, 2)
# spec-0313-51673-0112.csv
# (3522, 2)
# spec-0313-51673-0598.csv
# (3522, 2)
# spec-0315-51663-0024.csv
# (3522, 2)
# spec-0315-51663-0290.csv
# (3522, 2)
# spec-0326-52375-0213.csv
# (3522, 2)
# spec-0327-52294-0034.csv
# (3522, 2)
# spec-0328-52282-0053.csv
# (3522, 2)
# spec-0328-52282-0194.csv
# (3522, 2)
# spec-0329-52056-0036.csv
# (3522, 2)
# spec-0330-52370-0121.csv
# (3522, 2)
# spec-0331-52368-0048.csv
# (3522, 2)
# spec-0332-52367-0014.csv
# (3522, 2)
# spec-0333-52313-0002.csv
# (3522, 2)
# spec-0334-51993-0036.csv
# (3522, 2)
# spec-0334-51993-0130.csv
# (3522, 2)
# spec-0335-52000-0035.csv
# (3522, 2)
# spec-0335-52000-0037.csv
# (3522, 2)
# spec-0336-51999-0318.csv
# (3522, 2)
# spec-0337-51997-0069.csv
# (3522, 2)
# spec-0337-51997-0081.csv
# (3522, 2)
# spec-0338-51694-0002.csv
# (3522, 2)
# spec-0339-51692-0001.csv
# (3522, 2)
# spec-0340-51990-0135.csv
# (3522, 2)
# spec-0341-51690-0039.csv
# (3522, 2)
# spec-0342-51691-0161.csv
# (3522, 2)
# spec-0342-51691-0299.csv
# (3522, 2)
# spec-0343-51692-0178.csv
# (3522, 2)
# spec-0344-51693-0029.csv
# (3522, 2)
# spec-0344-51693-0500.csv
# (3522, 2)
# spec-0345-51690-0014.csv
# (3522, 2)
# spec-0346-51693-0110.csv
# (3522, 2)
# spec-0348-51671-0187.csv
# (3522, 2)
# spec-0348-51671-0260.csv
# (3522, 2)
# spec-0349-51699-0046.csv
# (3522, 2)
# spec-0350-51691-0026.csv
# (3522, 2)
# spec-0351-51695-0002.csv
# (3522, 2)
# spec-0352-51694-0115.csv
# (3522, 2)
# spec-0352-51694-0185.csv
# (3522, 2)
# spec-0353-51703-0040.csv
# (3522, 2)
# spec-0354-51792-0002.csv
# (3522, 2)
# spec-0355-51788-0030.csv
# (3522, 2)
# spec-0358-51818-0062.csv
# (3522, 2)
# spec-0358-51818-0067.csv
# (3522, 2)
# spec-0359-51821-0341.csv
# (3522, 2)
# spec-0360-51816-0609.csv
# (3522, 2)
# spec-0362-51999-0071.csv
# (3522, 2)
# spec-0363-51989-0039.csv
# (3522, 2)
# spec-0364-52000-0047.csv
# (3522, 2)
# spec-0364-52000-0050.csv
# (3522, 2)
# spec-0366-52017-0063.csv
# (3522, 2)
# spec-0366-52017-0535.csv
# (3522, 2)
# spec-0367-51997-0109.csv
# (3522, 2)
# spec-0371-52078-0104.csv
# (3522, 2)
# spec-0372-52173-0017.csv
# (3522, 2)
# spec-0373-51788-0314.csv
# (3522, 2)
# spec-0374-51791-0110.csv
# (3522, 2)
# spec-0374-51791-0331.csv
# (3522, 2)
# spec-0375-52140-0063.csv
# (3522, 2)
# spec-0376-52143-0023.csv
# (3522, 2)
# spec-0376-52143-0043.csv
# (3522, 2)
# spec-0377-52145-0036.csv
# (3522, 2)
# spec-0378-52146-0043.csv
# (3522, 2)
# spec-0379-51789-0111.csv
# (3522, 2)
# spec-0380-51792-0129.csv
# (3522, 2)
# spec-0381-51811-0040.csv
# (3522, 2)
# spec-0382-51816-0078.csv
# (3522, 2)
# spec-0383-51818-0007.csv
# (3522, 2)
# spec-0384-51821-0033.csv
# (3522, 2)
# spec-0385-51783-0117.csv
# (3522, 2)
# spec-0386-51788-0046.csv
# (3522, 2)
# spec-0387-51791-0034.csv
# (3522, 2)
# spec-0388-51793-0099.csv
# (3522, 2)
# spec-0389-51795-0150.csv
# (3522, 2)
# spec-0390-51900-0137.csv
# (3522, 2)
# spec-0391-51782-0066.csv
# (3522, 2)
# spec-0392-51793-0062.csv
# (3522, 2)
# spec-0392-51793-0161.csv
# (3522, 2)
# spec-0393-51794-0153.csv
# (3522, 2)
# spec-0394-51913-0046.csv
# (3522, 2)
# spec-0395-51783-0042.csv
# (3522, 2)
# spec-0396-51816-0088.csv
# (3522, 2)
# spec-0397-51794-0087.csv
# (3522, 2)
# spec-0397-51794-0511.csv
# (3522, 2)
# spec-0398-51789-0026.csv
# (3522, 2)
# spec-0399-51817-0034.csv
# (3522, 2)
# spec-0399-51817-0238.csv
# (3522, 2)
# spec-0400-51820-0152.csv
# (3522, 2)
# spec-0400-51820-0172.csv
# (3522, 2)
# spec-0401-51788-0014.csv
# (3522, 2)
# spec-0402-51793-0017.csv
# (3522, 2)
# spec-0403-51871-0107.csv
# (3522, 2)
# spec-0404-51812-0241.csv
# (3522, 2)
# spec-0405-51816-0132.csv
# (3522, 2)
# spec-0406-51817-0443.csv
# (3522, 2)
# spec-0406-51876-0198.csv
# (3522, 2)
# spec-0406-51876-0549.csv
# (3522, 2)
# spec-0407-51820-0183.csv
# (3522, 2)
# spec-0408-51821-0058.csv
# (3522, 2)
# spec-0409-51871-0037.csv
# (3522, 2)
# spec-0410-51877-0111.csv
# (3522, 2)
# spec-0411-51817-0030.csv
# (3522, 2)
# spec-0412-52258-0104.csv
# (3522, 2)
# spec-0412-52258-0378.csv
# (3522, 2)
# spec-0413-51821-0083.csv
# (3522, 2)
# spec-0414-51869-0027.csv
# (3267, 2)
# spec-0415-51810-0176.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-c0fd992af7a5> in <module>
#      17         print(spectrum.shape)
#      18         print(filename)
# ---> 19         data[i] = spectrum
#      20         labels[i] = directory
#      21         i += 1
#
# ValueError: could not broadcast input array from shape (3267,2) into shape (3522,2)

# %%
print(data.shape)
# Out:
# (4000, 3522, 2)
